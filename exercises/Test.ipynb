# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/callysto/data-files/main/Science/Climatograph/world-bank-climate-data-canada.csv'
weather = pd.read_csv(url) #the data from the url is read into the weather variable
weather
# Out:
#                                               Location   Annual     Jan  \
# 0                                               Canada   503.79   32.33
# 1    Northwest Territories / Territoires du Nord-Ouest   246.84   11.25
# 2                        Nova Scotia / Nouvelle-Écosse  1186.85  115.80
# 3                                              Nunavut   222.87    8.05
# 4                                              Ontario   681.84   40.74
# ..                                                 ...      ...     ...
# 107            British Columbia / Colombie-Britannique     1.70   -9.20
# 108                                              Yukon    -5.88  -23.29
# 109                                           Manitoba    -1.62  -21.28
# 110                  New Brunswick / Nouveau-Brunswick     4.54  -10.44
# 111  Newfoundland and Labrador / Terre-Neuve-et-Lab...    -1.02  -15.86
#
#        Feb     Mar    Apr    May    Jun    Jul    Aug    Sep     Oct     Nov  \
# 0    26.88   29.52  27.73  36.94  54.34  62.54  59.18  52.66   45.70   40.76
# 1    11.04   10.50  11.73  16.72  30.88  39.77  39.80  25.89   20.88   16.18
# 2    91.26  103.36  92.09  77.82  81.29  84.68  96.04  89.41  118.41  111.13
# 3     7.26    8.62  11.45  13.98  19.45  33.81  38.00  30.36   25.17   16.42
# 4    33.69   38.84  41.06  54.83  75.88  85.10  76.22  79.00   62.96   50.44
# ..     ...     ...    ...    ...    ...    ...    ...    ...     ...     ...
# 107  -7.38   -3.89   1.62   6.65  10.38  12.94  12.43   8.18    2.36   -5.11
# 108 -19.75  -15.55  -5.53   2.86   9.24  11.52   9.20   3.47   -4.92  -16.82
# 109 -19.15  -11.86  -2.15   6.19  13.09  16.76  15.46   9.40    1.21   -9.06
# 110  -9.22   -3.96   2.72   9.78  15.14  18.49  17.64  13.03    6.80    0.54
# 111 -15.63  -10.34  -3.57   3.08   8.76  13.22  12.90   8.27    2.28   -4.20
#
#         Dec           Type      Years
# 0     35.20  precipitation  1901-1930
# 1     12.19  precipitation  1901-1930
# 2    125.55  precipitation  1901-1930
# 3     10.31  precipitation  1901-1930
# 4     43.09  precipitation  1901-1930
# ..      ...            ...        ...
# 107   -8.56    temperature  1991-2020
# 108  -20.98    temperature  1991-2020
# 109  -18.09    temperature  1991-2020
# 110   -6.06    temperature  1991-2020
# 111  -11.13    temperature  1991-2020
#
# [112 rows x 16 columns]

# %%
temperature = weather[weather["Type"] == "temperature"] #filter data for temperatures and assign to temperature variable

print("June",temperature["Jun"].mean()) #calculate and print the average temperature value for June
print("August",temperature["Aug"].mean()) #calculate and print the average temperature value for August
# Out:
# June 10.649464285714286
# August 13.038749999999999

# %%
precipitation = weather[weather["Type"] == "precipitation"] #filter data for precipitation and assign to precipitation variable

print("June",precipitation["Jun"].mean()) #calculate and print the average precipitation value for June
print("August",precipitation["Aug"].mean()) #calculate and print the average precipitation value for August
# Out:
# June 67.29285714285716
# August 69.46125000000002
